# %% [markdown]
# # tokenization

# %%
H5AD_PATH = "/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/preprocessed_adipocytes_subset_2k.h5ad"

DATASET_NAME = "adipocytes_subset_obese_WL" # choose a name for the dataset
GENE_FILTERING_MODE = "all"  # one of: hvg, degs, all
HVG_MODE = "before_tokenisation"  # before_tokenisation or after_tokenisation


VAR_LIST = [
    "cell_states_adipocytes",
    "condition",
] # list of obs to retain in adata.vars after preprocessing


PAIRING_MODE = "stratified"  # stratified, random, mapping. We select the pairing strategy here, for more info please read the paper.
TIME_OBS = "condition" # the obs that contains the time point information for pairing
PAIRING_FILE = "path/to/pairing.csv"  # only if PAIRING_MODE == 'mapping'
MAIN_PAIRING_OBS = "cell_states_adipocytes"
OPT_PAIRING_OBS = []  # optional additional obs


NPROC = 8 # number of parallel processes to use
#N_HVG = 2000 # number of highly variable genes to select if HVG filtering is used
TIME_POINT_ORDER = ["obese", "weightloss"]
REFERENCE_TIME = "obese" # the reference time point for pairing, usually the control or untreated condition


GENE_MEDIAN_PATH = "/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/gene_median_dict_gftokens_gc95M.pkl"  # path to gene median dictionary, provided with Perturbgen for pretrained model
TOKEN_DICT_PATH  = "/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/token_dict_gftokens_gc95M.pkl"  # path to token dictionary, provided with Perturbgen for pretrained model
GENE_MAPPING_PATH = "/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/ensembl_mapping_dict_gc95M.pkl"  # path to gene mapping dictionary, Geneformer 95M mapping dictionary provided with Perturbgen

# %%
import subprocess
import sys

# %%
cmd = [
    sys.executable,
    "-m",
    "perturbgen",
    "tokenise",
    "--h5ad_path", H5AD_PATH,
    "--dataset", DATASET_NAME,
    "--gene_filtering_mode", GENE_FILTERING_MODE,
    "--hvg_mode", HVG_MODE,
    "--var_list", *VAR_LIST,
    "--pairing_mode", PAIRING_MODE,
    "--time_obs", TIME_OBS,
    "--main_pairing_obs", MAIN_PAIRING_OBS,
    "--nproc", str(NPROC),
    "--reference_time", REFERENCE_TIME,
    "--time_point_order", *TIME_POINT_ORDER,
    "--gene_median_path", GENE_MEDIAN_PATH,
    "--token_dict_path", TOKEN_DICT_PATH,
    "--gene_mapping_path", GENE_MAPPING_PATH,
]

# %%
print(sys.executable) 

print(" ".join(cmd))
# Out:
# /rds/general/user/ap5625/home/miniforge3/envs/perturbgen/bin/python
# /rds/general/user/ap5625/home/miniforge3/envs/perturbgen/bin/python -m perturbgen tokenise --h5ad_path /rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/preprocessed_adipocytes_subset_2k.h5ad --dataset adipocytes_subset_obese_WL --gene_filtering_mode all --hvg_mode before_tokenisation --var_list cell_states_adipocytes condition --pairing_mode stratified --time_obs condition --main_pairing_obs cell_states_adipocytes --nproc 8 --reference_time obese --time_point_order obese weightloss --gene_median_path /rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/gene_median_dict_gftokens_gc95M.pkl --token_dict_path /rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/token_dict_gftokens_gc95M.pkl --gene_mapping_path /rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/ensembl_mapping_dict_gc95M.pkl

# %%
subprocess.run(cmd, check=True)
# Out:
# loading, please wait...
# /rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/tokenizer.py:495: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   for i in adata.var["ensembl_id_collapsed"][coding_miRNA_loc]
# /rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/tokenizer.py:498: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   coding_miRNA_ids = adata.var["ensembl_id_collapsed"][coding_miRNA_loc]
# Current working directory: /rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling
# Start preprocessing adata...
# Number of genes dropped: 0
# Finished preprocessing adata.
# Start tokenisation of adata...
# Tokenizing /rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/T_perturb/tokenized_data/adipocytes_subset_obese_WL/h5ad_pairing_all_GF_genes/adipocytes_subset_obese_WL.h5ad
# /rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/T_perturb/tokenized_data/adipocytes_subset_obese_WL/h5ad_pairing_all_GF_genes/adipocytes_subset_obese_WL.h5ad has no column attribute 'filter_pass'; tokenizing all cells.
# Creating dataset.
# Map (num_proc=4): 100%|██████████| 1847/1847 [00:03<00:00, 525.14 examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 1847/1847 [00:00<00:00, 435560.52 examples/s]
# /rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/src/utils.py:1501: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata_obs_.groupby(grouping_obs)[time_obs].transform('nunique') == total_tps
# /rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/src/utils.py:1504: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = adata_grouped.groupby(grouping_obs)
# Finished tokenisation.
# Group ('Unassigned',) has no cells, skipping...
# Map (num_proc=8): 100%|██████████| 1847/1847 [00:00<00:00, 2864.73 examples/s]
# /rds/general/user/ap5625/home/miniforge3/envs/perturbgen/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /rds/general/user/ap5625/home/miniforge3/envs/perturbgen/lib/python3.11/site-packages/anndata/_core/anndata.py:1758: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
#
# Saving the dataset (0/1 shards):   0%|          | 0/1083 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 1083/1083 [00:00<00:00, 69343.74 examples/s]
# /rds/general/user/ap5625/home/miniforge3/envs/perturbgen/lib/python3.11/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
#
# Saving the dataset (0/1 shards):   0%|          | 0/1083 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100%|██████████| 1083/1083 [00:00<00:00, 103717.95 examples/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.91it/s]
# CompletedProcess(args=['/rds/general/user/ap5625/home/miniforge3/envs/perturbgen/bin/python', '-m', 'perturbgen', 'tokenise', '--h5ad_path', '/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/preprocessed_adipocytes_subset_2k.h5ad', '--dataset', 'adipocytes_subset_obese_WL', '--gene_filtering_mode', 'all', '--hvg_mode', 'before_tokenisation', '--var_list', 'cell_states_adipocytes', 'condition', '--pairing_mode', 'stratified', '--time_obs', 'condition', '--main_pairing_obs', 'cell_states_adipocytes', '--nproc', '8', '--reference_time', 'obese', '--time_point_order', 'obese', 'weightloss', '--gene_median_path', '/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/gene_median_dict_gftokens_gc95M.pkl', '--token_dict_path', '/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/token_dict_gftokens_gc95M.pkl', '--gene_mapping_path', '/rds/general/user/ap5625/projects/lms-scott-raw/live/Ada/perturbation_modeling/Perturbgen/perturbgen/pp/ensembl_mapping_dict_gc95M.pkl'], returncode=0)
