# %%
import scanpy as sc, pickle
src = sc.read_h5ad('/rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/T_perturb/tokenized_data/adipocytes_subset_obese_WL/h5ad_pairing_all_src/obese.h5ad')     # or whichever src path the yaml points to
print(src.shape, src.var_names[:5].tolist())

d = pickle.load(open('/rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/T_perturb/tokenized_data/adipocytes_subset_obese_WL/token_id_to_genename_all.pkl','rb'))
names = list(d.values())
print(len(names), names[:5])
# Out:
# (1083, 1974) ['ENSG00000244879', 'ENSG00000225269', 'ENSG00000174611', 'ENSG00000139352', 'ENSG00000232455']
# 1466 ['ENSG00000174611', 'ENSG00000139352', 'ENSG00000134242', 'ENSG00000081800', 'ENSG00000095564']
# /rds/general/user/ap5625/home/miniforge3/envs/perturbgen/lib/python3.11/site-packages/anndata/_core/anndata.py:1758: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
print(len(set(names) & set(src.var_names)), len(set(names) - set(src.var_names)))
# Out:
# 1462 4

# %%
print(sorted(set(names) - set(src.var_names)))
# Out:
# ['<cls>', '<eos>', '<mask>', '<pad>']

# %%
# does tokeid_to_rowid.pkl index the full 1974 gene space?
import pickle
p = '/rds/general/project/lms-scott-raw/live/Ada/perturbation_modeling/T_perturb/tokenized_data/adipocytes_subset_obese_WL/tokenid_to_rowid_all.pkl'
m = pickle.load(open(p, 'rb'))

print(type(m), len(m))
if isinstance(m, dict):
    vals = list(m.values())
else:
    vals = list(m)
print('min row id:', min(vals), 'max row id:', max(vals))
print('n unique:', len(set(vals)))
# Out:
# <class 'dict'> 1466
# min row id: 0 max row id: 1465
# n unique: 1466
